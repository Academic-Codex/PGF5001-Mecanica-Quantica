# %% [markdown]
# # Aula: Operadores de Momento Angular – Parte I
#
# Esta aula tem como objetivo **demonstrar matematicamente as propriedades fundamentais
# dos operadores de momento angular**, suas **relações de comutação**,
# a **ação dos operadores de subida e descida** sobre os estados de base |j,m⟩,
# e a **estrutura dos subespaços invariantes** associados a cada valor de j.
# Por fim, construímos explicitamente as **matrizes de representação** de Jₓ, Jᵧ, J_z e J_±
# para j = 1/2, 1 e 3/2.
#
# ---
#
# ## 0️⃣ Revisão de definições e relações fundamentais
#
# Relembramos as relações de comutação que definem a álgebra de Lie su(2):
#
# $$
# [J_i, J_j] = i\hbar \epsilon_{ijk} J_k
# $$
#
# A operação de rotação de um sistema quântico é representada por:
#
# $$
# U(\hat{n},\theta) = e^{-\frac{i}{\hbar}\theta\, \hat{n}\cdot\vec{J}}
# $$
#
# Além disso, definimos:
# $$
# J^2 = J_x^2 + J_y^2 + J_z^2
# $$
#
# e os autoestados simultâneos de $J^2$ e $J_z$:
#
# $$
# J^2 |j,m\rangle = \hbar^2 j(j+1) |j,m\rangle, \quad
# J_z |j,m\rangle = \hbar m |j,m\rangle
# $$
#
# ---
#
# ## 1️⃣ Determinação dos coeficientes de subida e descida $C_{j,m}$
#
# ### 🎯 Intenção
# Demonstrar que os operadores de subida e descida $J_+$ e $J_-$
# atuam sobre os estados de base elevando ou reduzindo o valor de $m$,
# e determinar explicitamente o coeficiente $C_{j,m}$ da transição.
#
# ### Passos matemáticos
#
# Definimos:
# $$
# J_+ = J_x + iJ_y, \quad J_- = J_x - iJ_y
# $$
#
# A ação desses operadores é:
# $$
# J_+ |j,m\rangle = C_{j,m}^+ |j,m+1\rangle, \quad
# J_- |j,m\rangle = C_{j,m}^- |j,m-1\rangle
# $$
#
# Sabemos que:
# $$
# \langle j,m|J_-J_+|j,m\rangle \ge 0
# $$
#
# e usando:
# $$
# J_-J_+ = J^2 - J_z^2 - \hbar J_z
# $$
#
# obtemos:
# $$
# \langle j,m|J_-J_+|j,m\rangle = \hbar^2 [j(j+1) - m(m+1)]
# $$
#
# Logo:
# $$
# |C_{j,m}^+|^2 = \hbar^2 (j - m)(j + m + 1)
# $$
#
# Adotando a convenção **real e positiva** (escolha de fase dos estados),
# $$
# C_{j,m}^+ = \hbar \sqrt{(j - m)(j + m + 1)}
# $$
#
# > 💡 *Intenção conceitual*:
# > Essa convenção fixa todas as fases relativas entre os estados |j,m⟩, garantindo consistência entre as representações matriciais.
#
# ---
#
# ## 2️⃣ Subespaços invariantes
#
# ### 🎯 Intenção
# Mostrar que o espaço de Hilbert se decompõe em subespaços
# $X_j = \mathrm{span}\{|j,m\rangle, m=-j,\dots,j\}$
# que são **invariantes sob rotações**.
#
# ### Desenvolvimento
#
# Um subespaço $X_j$ é dito invariante se:
# $$
# \hat{O}|\psi\rangle \in X_j, \quad \forall |\psi\rangle \in X_j
# $$
#
# Como $J^2$ comuta com todos os $J_i$,
# cada $X_j$ é preservado por qualquer rotação.
#
# $$
# \mathcal{X} = \bigoplus_j X_j
# $$
#
# Cada $X_j$ tem dimensão $2j+1$ e constitui uma **representação irredutível** da álgebra su(2).
#
# > 💡 *Intenção conceitual*:
# > Cada valor de j define um “bloco” independente na matriz de rotação —
# > essa decomposição leva à forma *block diagonal* das representações de rotação.
#
# ---
#
# ## 3️⃣ Construção explícita das matrizes de representação
#
# ### 🎯 Intenção
# Construir as representações matriciais explícitas de $J_z$, $J_+$ e $J_-$
# para diferentes valores de j, a partir da fórmula dos coeficientes $C_{j,m}$.
#
# ### Exemplo 1 – j = 1/2
# $$
# J_z = \frac{\hbar}{2}
# \begin{pmatrix}
# 1 & 0 \\
# 0 & -1
# \end{pmatrix}, \quad
# J_+ = \hbar
# \begin{pmatrix}
# 0 & 1 \\
# 0 & 0
# \end{pmatrix}
# $$
#
# Logo:
# $$
# \vec{J} = \frac{\hbar}{2}\vec{\sigma}
# $$
#
# onde $\vec{\sigma}$ são as matrizes de Pauli.
#
# ---
#
# ### Exemplo 2 – j = 1
# $$
# J_z = \hbar
# \begin{pmatrix}
# 1 & 0 & 0 \\
# 0 & 0 & 0 \\
# 0 & 0 & -1
# \end{pmatrix}
# ,\quad
# J_+ = \hbar
# \begin{pmatrix}
# 0 & \sqrt{2} & 0 \\
# 0 & 0 & \sqrt{2} \\
# 0 & 0 & 0
# \end{pmatrix}
# $$
#
# ---
#
# ### Exemplo 3 – j = 3/2
# $$
# J_z = \hbar
# \begin{pmatrix}
# \frac{3}{2} & 0 & 0 & 0 \\
# 0 & \frac{1}{2} & 0 & 0 \\
# 0 & 0 & -\frac{1}{2} & 0 \\
# 0 & 0 & 0 & -\frac{3}{2}
# \end{pmatrix}
# $$
#
# $$
# J_+ = \hbar
# \begin{pmatrix}
# 0 & \sqrt{3} & 0 & 0 \\
# 0 & 0 & 2 & 0 \\
# 0 & 0 & 0 & \sqrt{3} \\
# 0 & 0 & 0 & 0
# \end{pmatrix}
# $$
#
# > 💡 *Intenção conceitual*:
# > Esses operadores geram rotações entre os estados |j,m⟩ dentro de cada subespaço invariante.
# > A estrutura dos coeficientes mostra como o momento angular “gira” entre os valores de m.
#
# ---
#
# ## ✳️ Conclusão
#
# - O operador $J^2$ define os subespaços invariantes (representações irredutíveis).
# - Os operadores $J_+$ e $J_-$ conectam os estados dentro de cada subespaço.
# - O coeficiente $C_{j,m}$ é **real e positivo** pela convenção de fase adotada.
# - As matrizes de $J_x, J_y, J_z$ formam a base das representações da álgebra su(2),
#   com dimensões $2j+1$.
#
# ---

# %% [markdown]
# # Aula: Matrizes de Wigner e Representações de Rotação — Parte II
#
# ---
#
# ## 🎯 Objetivo da Aula
#
# Compreender como descrever **rotações quânticas** para qualquer valor de momento angular $j$,
# obtendo explicitamente as **matrizes de Wigner $D^{(j)}_{m'm}(\alpha,\beta,\gamma)$** e suas formas reduzidas $d^{(j)}_{m'm}(\beta)$.
#
# Estas matrizes são as **representações unitárias do grupo SU(2)**,
# que corresponde ao grupo de rotações quânticas (em contraste com o grupo clássico SO(3)).
#
# ---
#
# ## 1️⃣ Motivação conceitual
#
# Em Mecânica Quântica, qualquer rotação do sistema é descrita por um operador unitário
#
# $$
# \hat{U}(\hat{n}, \theta) = e^{-\frac{i}{\hbar}\theta\,\hat{n}\cdot\vec{J}}
# $$
#
# onde $\vec{J} = (J_x, J_y, J_z)$ são os operadores de momento angular.
#
# A ideia é determinar **como esse operador atua sobre os autoestados** $|j,m\rangle$ de $J^2$ e $J_z$:
#
# $$
# \hat{U}(\hat{n},\theta) |j,m\rangle = \sum_{m'} |j,m'\rangle D^{(j)}_{m'm}(\hat{n},\theta)
# $$
#
# com
#
# $$
# D^{(j)}_{m'm}(\hat{n},\theta) = \langle j,m'|\hat{U}(\hat{n},\theta)|j,m\rangle
# $$
#
# ---
#
# ## 2️⃣ Parametrização por ângulos de Euler
#
# ### 🎯 Intenção
# Expressar a rotação geral como a composição de **três rotações sucessivas** —
# duas em torno de $z$ e uma em torno de $y$.
#
# $$
# \hat{U}(\alpha,\beta,\gamma)
# = e^{-\frac{i}{\hbar}\alpha J_z}
#   e^{-\frac{i}{\hbar}\beta J_y}
#   e^{-\frac{i}{\hbar}\gamma J_z}
# $$
#
# onde $(\alpha, \beta, \gamma)$ são os **ângulos de Euler**.
#
# Assim:
#
# $$
# D^{(j)}_{m'm}(\alpha,\beta,\gamma)
# = \langle j,m'|
# e^{-\frac{i}{\hbar}\alpha J_z}
# e^{-\frac{i}{\hbar}\beta J_y}
# e^{-\frac{i}{\hbar}\gamma J_z}
# |j,m\rangle
# $$
#
# ---
#
# ## 3️⃣ Separação de fases e matriz reduzida
#
# Usando a linearidade da base de $|j,m\rangle$:
#
# $$
# D^{(j)}_{m'm}(\alpha,\beta,\gamma)
# = e^{-i\alpha m'} \, d^{(j)}_{m'm}(\beta) \, e^{-i\gamma m}
# $$
#
# onde
#
# $$
# d^{(j)}_{m'm}(\beta)
# = \langle j,m'|e^{-\frac{i}{\hbar}\beta J_y}|j,m\rangle
# $$
#
# é chamada de **matriz de rotação reduzida**, e é **real**.
#
# > 💡 *Intenção conceitual*:
# > O termo $d^{(j)}_{m'm}(\beta)$ codifica o efeito “puro” da rotação,
# > enquanto as fases $e^{-i\alpha m'}$ e $e^{-i\gamma m}$ correspondem
# > às rotações em torno de $z$.
#
# ---
#
# ## 4️⃣ Exemplos
#
# ### Caso $j=0$
# $$
# d^{(0)}(\beta) = [1]
# $$
# A rotação não altera o estado — o escalar é invariante.
#
# ### Caso $j=\frac{1}{2}$
# Usando $J_y = \frac{\hbar}{2}\sigma_y$:
#
# $$
# e^{-\frac{i}{\hbar}\beta J_y}
# = e^{-\frac{i}{2}\beta \sigma_y}
# = \cos\frac{\beta}{2}\,I - i\sigma_y\sin\frac{\beta}{2}
# $$
#
# $$
# \Rightarrow d^{(1/2)}(\beta)
# = \begin{pmatrix}
# \cos\frac{\beta}{2} & -\sin\frac{\beta}{2} \\
# \sin\frac{\beta}{2} & \cos\frac{\beta}{2}
# \end{pmatrix}
# $$
#
# > 💡 *Intenção*: conectar SU(2) e SO(3).
# > Note que $d^{(1/2)}(\beta)$ é **real**, e a matriz é **ortogonal**,
# > apesar de $U$ ser unitário e complexo.
#
# ---
#
# ## 5️⃣ Relação entre os grupos SO(3) e SU(2)
#
# | Mundo       | Grupo  | Natureza | Estrutura da rotação |
# |--------------|---------|-----------|----------------------|
# | Clássico (Euler) | SO(3) | real, ortogonal | $R = R_z(\alpha) R_y(\beta) R_z(\gamma)$ |
# | Quântico (spin) | SU(2) | complexo, unitário | $U = e^{-i\alpha J_z/\hbar} e^{-i\beta J_y/\hbar} e^{-i\gamma J_z/\hbar}$ |
#
# > 💡 SU(2) é o **cobrimento duplo** de SO(3):
# > uma rotação de $2\pi$ em SU(2) muda o sinal do estado quântico,
# > mas não altera observáveis físicos.
#
# ---
#
# ## 6️⃣ Subespaços invariante e operadores de rotação
#
# O operador de rotação $\hat{O} = f(\vec{J})$ **não muda j**:
#
# $$
# \hat{O}|j,m\rangle = \sum_{m'} |j,m'\rangle \langle j,m'|\hat{O}|j,m\rangle
# $$
#
# Logo, cada subespaço $X_j = \text{span}\{|j,m\rangle\}$ é fechado sob rotação
# e tem dimensão $2j + 1$.
#
# Assim, $D^{(j)}(\alpha,\beta,\gamma)$ é uma matriz quadrada de dimensão $(2j+1)\times(2j+1)$.
#
# ---
#
# ## 7️⃣ Exemplos finais e interpretação física
#
# - Para $j=0$: a rotação não tem efeito → **escalares invariantes**.
# - Para $j=\frac{1}{2}$: rotação de spin ½ → representação de Pauli.
# - Para $j=1$: rotação de vetores no espaço tridimensional → representação clássica SO(3).
#
# ---
#
# ## ✳️ Conclusão
#
# - O operador $U(\alpha,\beta,\gamma)$ gera rotações em SU(2).
# - As matrizes $D^{(j)}_{m'm}$ são suas representações em cada subespaço $X_j$.
# - A parte reduzida $d^{(j)}_{m'm}(\beta)$ é **real** e contém toda a estrutura angular.
# - O número quântico $j$ define a **dimensão do subespaço** e a **representação** do grupo.
#
# ---
#
# 📘 **Próxima aula – Parte III:**
# Cálculo explícito das matrizes $d^{(j)}(\beta)$ para $j=1, \frac{3}{2}$
# e a conexão com os **polinômios de Legendre associados**.
